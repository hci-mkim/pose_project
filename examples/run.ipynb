# %%
# Video to Image
# !python vid2img.py

# %%
# yolact(background rejection)
# %cd yolact/
# !python eval.py --trained_model=weights/yolact_resnet50_54_800000.pth --score_threshold=0.7 --top_k=1 --images="../inputs":"../outputs_background_removed"
# %cd ..
# Out:
# jpg
# ..\inputs\2019WHA2.avi_00149.jpg -> ../outputs\2019WHA2.avi_00149.jpg
# ..\inputs\2019WHA2.avi_00150.jpg -> ../outputs\2019WHA2.avi_00150.jpg
# ..\inputs\2019WHA2.avi_00151.jpg -> ../outputs\2019WHA2.avi_00151.jpg
# ..\inputs\2019WHA2.avi_00152.jpg -> ../outputs\2019WHA2.avi_00152.jpg
# ..\inputs\2019WHA2.avi_00153.jpg -> ../outputs\2019WHA2.avi_00153.jpg
# ..\inputs\2019WHA2.avi_00154.jpg -> ../outputs\2019WHA2.avi_00154.jpg
# ..\inputs\2019WHA2.avi_00155.jpg -> ../outputs\2019WHA2.avi_00155.jpg
# ..\inputs\2019WHA2.avi_00156.jpg -> ../outputs\2019WHA2.avi_00156.jpg
# ..\inputs\2019WHA2.avi_00157.jpg -> ../outputs\2019WHA2.avi_00157.jpg
# ..\inputs\2019WHA2.avi_00158.jpg -> ../outputs\2019WHA2.avi_00158.jpg
# ..\inputs\2019WHA22.avi_00001.jpg -> ../outputs\2019WHA22.avi_00001.jpg
# ..\inputs\2019WHA22.avi_00002.jpg -> ../outputs\2019WHA22.avi_00002.jpg
# ..\inputs\2019WHA22.avi_00003.jpg -> ../outputs\2019WHA22.avi_00003.jpg
# ...

# %%
# keypoint
# !python custom_image_demo.py
# Out:
# not found
# not found
# not found
# under score.. :(
# under score.. :(
# under score.. :(
# under score.. :(
# not found
# under score.. :(
# under score.. :(
# under score.. :(
# under score.. :(
# under score.. :(
# under score.. :(
# under score.. :(
# under score.. :(
# not found
# under score.. :(
# under score.. :(
# under score.. :(
# under score.. :(
# under score.. :(
# under score.. :(
# not found
# under score.. :(
# under score.. :(
# not found
# under score.. :(
# under score.. :(
# under score.. :(
# under score.. :(
# under score.. :(
# under score.. :(
# under score.. :(
# not found
# under score.. :(
# under score.. :(
# under score.. :(
# under score.. :(
# under score.. :(
# under score.. :(
# not found
# under score.. :(
# under score.. :(
# under score.. :(
# under score.. :(
# under score.. :(
# under score.. :(
# not found
# under score.. :(
# not found
# under score.. :(
# under score.. :(
# not found
# under score.. :(
# under score.. :(
# ...
