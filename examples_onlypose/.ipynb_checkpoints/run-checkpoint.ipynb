# %%
# Video to Image
# !python vid2img.py
# Out:
# ['golf.mp4', 'golf1.mp4']

# %%
# yolact(background rejection)
# %cd yolact/
# !python eval.py --trained_model=weights/yolact_resnet50_54_800000.pth --score_threshold=0.7 --top_k=1 --images="../[2]inputs":"../[3]outputs_background_removed"
# %cd ..
# Out:
# C:\Users\min11\Desktop\coding\rcnnpose-pytorch\examples\yolact
# Config not specified. Parsed yolact_resnet50_config from the file name.
#
# Loading model... Done.
#
# ..\[2]inputs\golf.mp4_00001.jpg -> ../[3]outputs_background_removed\golf.mp4_00001.jpg
# ..\[2]inputs\golf.mp4_00002.jpg -> ../[3]outputs_background_removed\golf.mp4_00002.jpg
# ..\[2]inputs\golf.mp4_00003.jpg -> ../[3]outputs_background_removed\golf.mp4_00003.jpg
# ..\[2]inputs\golf.mp4_00004.jpg -> ../[3]outputs_background_removed\golf.mp4_00004.jpg
# ..\[2]inputs\golf.mp4_00005.jpg -> ../[3]outputs_background_removed\golf.mp4_00005.jpg
# ..\[2]inputs\golf.mp4_00006.jpg -> ../[3]outputs_background_removed\golf.mp4_00006.jpg
# ..\[2]inputs\golf.mp4_00007.jpg -> ../[3]outputs_background_removed\golf.mp4_00007.jpg
# ..\[2]inputs\golf.mp4_00008.jpg -> ../[3]outputs_background_removed\golf.mp4_00008.jpg
# ..\[2]inputs\golf.mp4_00009.jpg -> ../[3]outputs_background_removed\golf.mp4_00009.jpg
# ...

# %%
# keypoint
# !python custom_image_demo.py
# Out:
# under score.. :(
# under score.. :(
# under score.. :(
# under score.. :(
# under score.. :(
# under score.. :(
# under score.. :(
# under score.. :(
# under score.. :(
# under score.. :(
# not found
# under score.. :(
# under score.. :(
# under score.. :(
# under score.. :(
# under score.. :(
# under score.. :(
# under score.. :(
# under score.. :(
# not found
# under score.. :(
# under score.. :(
# under score.. :(
# under score.. :(
# under score.. :(
# under score.. :(
# under score.. :(
# under score.. :(
# not found
# under score.. :(
# under score.. :(
# under score.. :(
# under score.. :(
# under score.. :(
# under score.. :(
# under score.. :(
# under score.. :(
# under score.. :(
# under score.. :(
# not found
# under score.. :(
# under score.. :(
# under score.. :(
# under score.. :(
# under score.. :(
# under score.. :(
#                         file_name  nose   neck  ...  knee_r  ankle_l  ankle_r
# ...
